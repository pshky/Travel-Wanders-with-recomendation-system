# %%
import pandas as pd
import numpy as np
import mysql.connector
from sqlalchemy import create_engine

# %%
def db_connect():
    database_name = 'travelwanders' 
    db = mysql.connector.connect(host='localhost', user='root', password='', database='travelwanders')
    return db

# %%
def fetch_db_data():
    db = db_connect()
    cursor = db.cursor(buffered=True)
    tb_list = ['r_location','r_ratings']
    result = []
    for tb in tb_list:
        sql = 'select * from '+tb
        cursor.execute(sql)
        tb = cursor.fetchall()
        result.append(tb)
    return result[0],result[1]

# %%
location,ratings = fetch_db_data()

# %%
location = pd.DataFrame(data=location,columns=['location_id','city','destination','description','index','image_url'])
ratings = pd.DataFrame(data=ratings,columns=['u_id','index','location_rating'])

# %%
location
# Out:
#     location_id       city                 destination  \
# 0             1  Kathmandu     Kathmandu Durbar Square
# 1             2  Kathmandu  Shree Pashupatinath Temple
# 2             3  Kathmandu         Swayambhunath Stupa
# 3             4    pokhara          Gupteswor mahadev
# 4             5    pokhara               Mahendra cave
# ..          ...        ...                         ...
# 61           62   Kirtipur                     TauDaha
# 62           63   Kirtipur                      Chovar
# 63           64   Kirtipur                  Dev Pukkhu
# 64           65    Pokhara                    Ghandruk
# 65           66    Chitwan       Chitwan national park
#
#                                           description  index  \
# 0   It is one of three Durbar Squares in the Kathm...     10
# 1   It is one of the 5 holiest Shiva temple in the...     11
# 2   It is the oldest temple standing in Nepal whos...     12
# 3   Gupteshwor Mahadev Cave is considered the long...     13
# 4   Mahendra Cave is a cave located in Pokhara-16,...     14
# ..                                                ...    ...
# 61  Taudaha?Lake is a small lake in the outskirts ...     77
# 62  Chobhar is a village in Kathmandu District in ...     78
# 63  center of attraction every year during Indra J...     79
# 64  It is an old gurung village located on the out...     43
# 65  hitwan National Park is a preserved area in th...     81
#
#                                             image_url
# 0   https://www.inditales.com/wp-content/uploads/2...
# 1   https://bsmedia.business-standard.com/_media/b...
# 2   https://worldtravelfamily.com/wp-content/uploa...
# 3   https://www.vivaanadventure.com/wp-content/upl...
# 4   https://www.holidify.com/images/cmsuploads/com...
# ..                                                ...
# 61  https://www.khojnu.com/wp-content/uploads/2018...
# 62  https://www.teensyideas.com/wp-content/uploads...
# 63  https://3.bp.blogspot.com/-_jLLD6WPwCI/WKVnMn7...
# 64  https://assets-cdn.kathmandupost.com/uploads/s...
# 65  https://www.andbeyond.com/wp-content/uploads/s...
#
# [66 rows x 6 columns]

# %%
ratings
# Out:
#      u_id  index  location_rating
# 0       1     10             10.0
# 1       1     11              9.0
# 2       1     12             10.0
# 3       1     13              7.0
# 4       1     14              5.5
# ..    ...    ...              ...
# 696    10     76              8.0
# 697    10     77             10.0
# 698    10     78              9.0
# 699    10     79              9.0
# 700     8     12             10.0
#
# [701 rows x 3 columns]

# %%
print(location.shape)
print(ratings.shape)
# Out:
# (66, 6)
# (701, 3)

# %%
location.isnull().sum()
# Out:
# location_id    0
# city           0
# destination    0
# description    0
# index          0
# image_url      0
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# u_id               0
# index              0
# location_rating    0
# dtype: int64

# %%
location.duplicated().sum()
# Out:
# 0

# %%
ratings_with_name = ratings.merge(location,on='index')

# %%
ratings_with_name
# Out:
#      u_id  index  location_rating  location_id       city  \
# 0       1     10             10.0            1  Kathmandu
# 1       2     10              8.0            1  Kathmandu
# 2       3     10              5.0            1  Kathmandu
# 3       4     10             10.0            1  Kathmandu
# 4       5     10              9.0            1  Kathmandu
# ..    ...    ...              ...          ...        ...
# 646     6     79              1.0           64   Kirtipur
# 647     7     79              1.0           64   Kirtipur
# 648     8     79              4.0           64   Kirtipur
# 649     9     79              3.0           64   Kirtipur
# 650    10     79              9.0           64   Kirtipur
#
#                  destination  \
# 0    Kathmandu Durbar Square
# 1    Kathmandu Durbar Square
# 2    Kathmandu Durbar Square
# 3    Kathmandu Durbar Square
# 4    Kathmandu Durbar Square
# ..                       ...
# 646               Dev Pukkhu
# 647               Dev Pukkhu
# 648               Dev Pukkhu
# 649               Dev Pukkhu
# 650               Dev Pukkhu
#
#                                            description  \
# 0    It is one of three Durbar Squares in the Kathm...
# 1    It is one of three Durbar Squares in the Kathm...
# 2    It is one of three Durbar Squares in the Kathm...
# 3    It is one of three Durbar Squares in the Kathm...
# 4    It is one of three Durbar Squares in the Kathm...
# ..                                                 ...
# 646  center of attraction every year during Indra J...
# 647  center of attraction every year during Indra J...
# 648  center of attraction every year during Indra J...
# 649  center of attraction every year during Indra J...
# 650  center of attraction every year during Indra J...
#
#                                              image_url
# 0    https://www.inditales.com/wp-content/uploads/2...
# 1    https://www.inditales.com/wp-content/uploads/2...
# 2    https://www.inditales.com/wp-content/uploads/2...
# 3    https://www.inditales.com/wp-content/uploads/2...
# 4    https://www.inditales.com/wp-content/uploads/2...
# ..                                                 ...
# 646  https://3.bp.blogspot.com/-_jLLD6WPwCI/WKVnMn7...
# 647  https://3.bp.blogspot.com/-_jLLD6WPwCI/WKVnMn7...
# 648  https://3.bp.blogspot.com/-_jLLD6WPwCI/WKVnMn7...
# 649  https://3.bp.blogspot.com/-_jLLD6WPwCI/WKVnMn7...
# 650  https://3.bp.blogspot.com/-_jLLD6WPwCI/WKVnMn7...
#
# [651 rows x 8 columns]

# %%
num_rating_df = ratings_with_name.groupby('destination').count()['location_rating'].reset_index()
num_rating_df.rename(columns={'location_rating':'num_ratings'},inplace=True)
num_rating_df
# Out:
#                 destination  num_ratings
# 0            Ashokan Pillar           10
# 1       Bagh Bhairab Temple           10
# 2        Banglamukhi Temple           10
# 3               Begnas Lake           10
# 4   Bhaktapur Durbar Square           10
# ..                      ...          ...
# 59       World Peace Pagoda           20
# 60               chandagiri           10
# 61       khumbeshwar temple           10
# 62              patan dhoka           10
# 63             patan museum           10
#
# [64 rows x 2 columns]

# %%
avg_rating_df = ratings_with_name.groupby('destination').mean()['location_rating'].reset_index()
avg_rating_df.rename(columns={'location_rating':'avg_rating'},inplace=True)
avg_rating_df
# Out:
#                 destination  avg_rating
# 0            Ashokan Pillar        5.90
# 1       Bagh Bhairab Temple        5.95
# 2        Banglamukhi Temple        4.95
# 3               Begnas Lake        4.25
# 4   Bhaktapur Durbar Square        5.95
# ..                      ...         ...
# 59       World Peace Pagoda        6.20
# 60               chandagiri        5.44
# 61       khumbeshwar temple        5.65
# 62              patan dhoka        4.75
# 63             patan museum        6.05
#
# [64 rows x 2 columns]

# %%
popular_df=num_rating_df.merge(avg_rating_df,on='destination')
popular_df
# Out:
#                 destination  num_ratings  avg_rating
# 0            Ashokan Pillar           10        5.90
# 1       Bagh Bhairab Temple           10        5.95
# 2        Banglamukhi Temple           10        4.95
# 3               Begnas Lake           10        4.25
# 4   Bhaktapur Durbar Square           10        5.95
# ..                      ...          ...         ...
# 59       World Peace Pagoda           20        6.20
# 60               chandagiri           10        5.44
# 61       khumbeshwar temple           10        5.65
# 62              patan dhoka           10        4.75
# 63             patan museum           10        6.05
#
# [64 rows x 3 columns]

# %%
popular_df = popular_df[popular_df['num_ratings']>=5].sort_values('avg_rating',ascending=False).head(60)

# %%
popular_df = popular_df.merge(location,on='destination').drop_duplicates('destination')[['location_id','index','destination','city','description','image_url','num_ratings','avg_rating']]

# %%
popular_df
# Out:
#     location_id  index                    destination       city  \
# 0             3     12            Swayambhunath Stupa  Kathmandu
# 1             1     10        Kathmandu Durbar Square  Kathmandu
# 2             2     11     Shree Pashupatinath Temple  Kathmandu
# 3            11     20            Srilankan Monastary    Lumbini
# 4            32     41                      Fewa Lake    Pokhara
# 5            31     40                      Lake Side    Pokhara
# 6            12     21                 Maya Devi Pond    Lumbini
# 7             4     13             Gupteswor mahadev     pokhara
# 8            10     19                  Hanuman dhoka  Kathmandu
# 9            58     73  Nagar Mandap Shri Kirti bihar   Kirtipur
# 10           23     32                       Nagarkot  Bhaktapur
# 11           44     60               Boudanath Temple  Kathmandu
# 12           49     63               Maya Devi Temple    Lumbini
# 13           47     61     Tinthana Suspension Bridge   Kirtipur
# 14            8     17                    White Gumba  Kathmandu
# 15           20     29      Rato Machindranath Temple   Lalitpur
# 16           54     68           The Garden of Dreams  Kathmandu
# 17           35     44                      Poon Hill    Pokhara
# 18           36     45             World Peace Pagoda    Pokhara
# 20           43     52                   patan museum   Lalitpur
# 21           34     43                      Sarangkot    Pokhara
# 22           57     72            Bagh Bhairab Temple   Kirtipur
# 23           21     30        Bhaktapur Durbar Square  Bhaktapur
# 24           65     43                       Ghandruk    Pokhara
# 25           42     51                       Pumdikot    Pokhara
# 26           50     64            Patan Durbar Square   Lalitpur
# 27           61     76                 Ashokan Pillar    Lumbini
# 28           55     70         Lumbini Crane Santuary    Lumbini
# 29            9     18                     Davis Fall    Pokhara
# 30           18     27               Pimbahal Pokhari   Lalitpur
# 31           14     23               Lakuri Bhanjyang   Lalitpur
# 32           59     74          Uma Mahaeshwor Temple   Kirtipur
# 33           39     48             khumbeshwar temple   Lalitpur
# 34           33     42                    Central Zoo   Lalitpur
# 35           63     78                         Chovar   Kirtipur
# 36           19     28                        NagDaha   Lalitpur
# 37           27     36              Pilot Baba Ashram  Bhaktapur
# 38           28     37             KailashNath Temple  Bhaktapur
# 39           56     71                     Tilaurakot    Lumbini
# 40           13     22                  Talaju mandir  Kathmandu
# 41           51     65                     chandagiri  Kathmandu
# 42           17     26              Mahabuddha Temple   Lalitpur
# 43            6     15                      Nagarjung  Kathmandu
# 44           60     75                 Kirtipur Gumba   Kirtipur
# 45           45     69                         Thamel  Kathmandu
# 46           15     24      Godavari Botanical Garden   Lalitpur
# 47            7     16                 Tribhuwan Park  Kathmandu
# 48           16     25             Banglamukhi Temple   Lalitpur
# 40  https://upload.wikimedia.org/wikipedia/commons...           10    5.450000
# 41  https://www.visionsoftravel.org/wp-content/upl...           10    5.440000
# 42  https://gallery.thelongestwayhome.com/img/s12/...           10    5.400000
# 43  https://snnp.gov.np/wp-content/uploads/2020/12...           10    5.400000
# 44  https://i.pinimg.com/originals/aa/4c/ad/aa4cad...           10    5.400000
# 45  https://dynamic-media-cdn.tripadvisor.com/medi...           10    5.280000
# 46  https://wonderguides.imgix.net/media/image/pri...           10    5.150000
# 47  https://dynamic-media-cdn.tripadvisor.com/medi...           10    5.100000
# 48  https://www.khojnu.com/wp-content/uploads/2021...           10    4.950000
# 49  https://www.villagehighlandresort.com/wp-conte...           10    4.900000
# 50  https://www.khojnu.com/wp-content/uploads/2018...           10    4.900000
# 51  https://www.templepurohit.com/wp-content/uploa...           10    4.810000
# 52  https://3.bp.blogspot.com/-_jLLD6WPwCI/WKVnMn7...           10    4.800000
# 53  https://dynamic-media-cdn.tripadvisor.com/medi...           10    4.750000
# 54  https://www.holidify.com/images/cmsuploads/com...           10    4.700000
# 55  https://colzlife.com/wp-content/uploads/2021/0...           10    4.650000
# 56  https://dynamic-media-cdn.tripadvisor.com/medi...           10    4.550000
# 57  https://www.redcarpetjourney.com/wp-content/up...           10    4.500000
# 58  https://cdn.elebase.io/173fe953-8a63-4a8a-8ca3...           10    4.490000
# 59  https://media.tacdn.com/media/attractions-spli...           10    4.400000
# 60  https://www.holidify.com/images/cmsuploads/com...           10    4.250000

# %%
engine = create_engine('mysql+mysqlconnector://root:@localhost:3306/travelwanders')
popular_df.to_sql(name='final_popular', con=engine, if_exists='replace', index=False)
# Out:
# 60

# %%
x = ratings_with_name.groupby('u_id').count()['location_rating'] >10
most_users = x[x].index

# %%
filtered_rating = ratings_with_name[ratings_with_name['u_id'].isin(most_users)]

# %%
y = filtered_rating.groupby('destination').count()['location_rating'] >=2
famous_destination = y[y].index

# %%
final_ratings = filtered_rating[filtered_rating['destination'].isin(famous_destination)]

# %%
pt = final_ratings.pivot_table(index='destination',columns='u_id',values='location_rating')

# %%
pt
# Out:
# u_id                       1    2    3     4     5    6    7     8     9   \
# destination
# Ashokan Pillar           5.00  5.0  5.0   4.0   7.0  4.0  8.0  4.00  9.00
# Bagh Bhairab Temple      7.00  6.0  4.0   4.0   7.5  7.0  8.0  7.00  3.00
# Banglamukhi Temple       7.00  5.0  5.0   3.0   5.0  4.5  5.0  7.00  5.00
# Begnas Lake              6.00  5.0  3.0   5.0   4.5  5.0  1.0  6.00  3.50
# Bhaktapur Durbar Square  8.00  4.0  5.0  10.0  10.0  3.0  3.0  8.00  3.50
# ...                       ...  ...  ...   ...   ...  ...  ...   ...   ...
# World Peace Pagoda       6.75  5.0  5.0   7.0   7.0  9.5  6.5  6.75  2.75
# chandagiri               7.30  0.0  4.5   NaN   5.0  7.0  6.3  7.30  3.50
# khumbeshwar temple       9.00  4.0  5.0   5.0   7.0  5.0  4.0  9.00  3.50
# patan dhoka              8.00  5.0  3.0   3.0   6.0  3.0  4.0  8.00  4.00
# patan museum             9.00  7.0  4.0   4.0  10.0  5.0  4.0  9.00  3.50
#
# u_id                       10
# destination
# Ashokan Pillar           8.00
# Bagh Bhairab Temple      6.00
# Banglamukhi Temple       3.00
# Begnas Lake              3.50
# Bhaktapur Durbar Square  5.00
# ...                       ...
# World Peace Pagoda       5.75
# chandagiri               9.00
# khumbeshwar temple       5.00
# patan dhoka              3.50
# patan museum             5.00
#
# [64 rows x 10 columns]

# %%
pt.fillna(0,inplace=True)

# %%
pt
# Out:
# u_id                       1    2    3     4     5    6    7     8     9   \
# destination
# Ashokan Pillar           5.00  5.0  5.0   4.0   7.0  4.0  8.0  4.00  9.00
# Bagh Bhairab Temple      7.00  6.0  4.0   4.0   7.5  7.0  8.0  7.00  3.00
# Banglamukhi Temple       7.00  5.0  5.0   3.0   5.0  4.5  5.0  7.00  5.00
# Begnas Lake              6.00  5.0  3.0   5.0   4.5  5.0  1.0  6.00  3.50
# Bhaktapur Durbar Square  8.00  4.0  5.0  10.0  10.0  3.0  3.0  8.00  3.50
# ...                       ...  ...  ...   ...   ...  ...  ...   ...   ...
# World Peace Pagoda       6.75  5.0  5.0   7.0   7.0  9.5  6.5  6.75  2.75
# chandagiri               7.30  0.0  4.5   0.0   5.0  7.0  6.3  7.30  3.50
# khumbeshwar temple       9.00  4.0  5.0   5.0   7.0  5.0  4.0  9.00  3.50
# patan dhoka              8.00  5.0  3.0   3.0   6.0  3.0  4.0  8.00  4.00
# patan museum             9.00  7.0  4.0   4.0  10.0  5.0  4.0  9.00  3.50
#
# u_id                       10
# destination
# Ashokan Pillar           8.00
# Bagh Bhairab Temple      6.00
# Banglamukhi Temple       3.00
# Begnas Lake              3.50
# Bhaktapur Durbar Square  5.00
# ...                       ...
# World Peace Pagoda       5.75
# chandagiri               9.00
# khumbeshwar temple       5.00
# patan dhoka              3.50
# patan museum             5.00
#
# [64 rows x 10 columns]

# %%
import matplotlib.pyplot as  plt
# %matplotlib inline

# %%
plt.scatter(popular_df['avg_rating'],popular_df['destination'])

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_scores = cosine_similarity(pt)

# %%
similarity_scores.shape
# Out:
# (64, 64)

# %%
predicted_values = []
def recommend(location_name):
    temp_list = []
    #index fetch
    index = np.where(pt.index==location_name)[0][0]
    similar_items=sorted(list(enumerate(similarity_scores[index])),key=lambda x:x[1],reverse=True)[1:6]
    
    for i in similar_items:
        item = []
        item_df = pt.index[i[0]]
        
        temp_list.append(item_df)
    predicted_values.append(temp_list)

# %%
n_pt = pt.reset_index()
destination_list = n_pt['destination'].values

# %%
for d in destination_list:
    recommend(d)

# %%
final_df = pd.DataFrame( data = destination_list)

# %%
ndf = pd.DataFrame(data=predicted_values)
ndf['place'] = destination_list

# %%
pivot_df = ndf.melt(id_vars=["place"], 
        var_name="column",
        value_name="destination").sort_values(by='place')

# %%
pivot_df = pivot_df[['place','destination']]
pivot_df.head()
# Out:
#               place       destination
# 0    Ashokan Pillar    Maya Devi Pond
# 192  Ashokan Pillar     Mahendra cave
# 128  Ashokan Pillar            Thamel
# 256  Ashokan Pillar    Kirtipur Gumba
# 64   Ashokan Pillar  Maya Devi Temple

# %%
new_pivot_df = pivot_df.merge(location,on='destination')

# %%
new_pivot_df
# Out:
#                      place              destination  location_id       city  \
# 0           Ashokan Pillar           Maya Devi Pond           12    Lumbini
# 1          Chilancho Bahal           Maya Devi Pond           12    Lumbini
# 2    Lumbini Monastic Site           Maya Devi Pond           12    Lumbini
# 3         Maya Devi Temple           Maya Devi Pond           12    Lumbini
# 4      Srilankan Monastary           Maya Devi Pond           12    Lumbini
# ..                     ...                      ...          ...        ...
# 319      Mahabuddha Temple         Lakuri Bhanjyang           14   Lalitpur
# 320         Maya Devi Pond           Ashokan Pillar           61    Lumbini
# 321       Maya Devi Temple           Ashokan Pillar           61    Lumbini
# 322    Srilankan Monastary    Lumbini Monastic Site           48    Lumbini
# 323             Sundarijal  Bhaktapur Durbar Square           21  Bhaktapur
#
#                                            description  index  \
# 0    It is an ancient pond of huge significane loca...     21
# 1    It is an ancient pond of huge significane loca...     21
# 2    It is an ancient pond of huge significane loca...     21
# 3    It is an ancient pond of huge significane loca...     21
# 4    It is an ancient pond of huge significane loca...     21
# ..                                                 ...    ...
# 319  It is a viewpoint/hiking area located in the f...     23
# 320  A pillar inscribed by the Great indian emperor...     76
# 321  A pillar inscribed by the Great indian emperor...     76
# 322  It the monasic site of Lumbini.One of the larg...     62
# 323  It is one of three Durbar Squares in the Kathm...     30
#
#                                              image_url
# 0    https://visitsnepal.com/wp-content/uploads/202...
# 1    https://visitsnepal.com/wp-content/uploads/202...
# 2    https://visitsnepal.com/wp-content/uploads/202...
# 3    https://visitsnepal.com/wp-content/uploads/202...
# 4    https://visitsnepal.com/wp-content/uploads/202...
# ..                                                 ...
# 319  https://www.ghztreks.com/wp-content/uploads/20...
# 320  [https://upload.wikimedia.org/wikipedia/common...
# 321  [https://upload.wikimedia.org/wikipedia/common...
# 322  https://www.holidify.com/images/cmsuploads/com...
# 323  https://media-cdn.tripadvisor.com/media/attrac...
#
# [324 rows x 7 columns]

# %%
new_pivot_df = new_pivot_df[['place','destination','image_url']]
new_pivot_df = new_pivot_df.sort_values(by='place')

# %%
engine = create_engine('mysql+mysqlconnector://root:@localhost:3306/travelwanders')
new_pivot_df.to_sql(name='final_prediction', con=engine, if_exists='replace', index=False)
# Out:
# 324

# %%
new_pivot_df
# Out:
#               place            destination  \
# 0    Ashokan Pillar         Maya Devi Pond
# 24   Ashokan Pillar         Kirtipur Gumba
# 13   Ashokan Pillar                 Thamel
# 5    Ashokan Pillar          Mahendra cave
# 28   Ashokan Pillar       Maya Devi Temple
# ..              ...                    ...
# 145    patan museum  Changu Narayan Temple
# 137    patan museum               Pumdikot
# 96     patan museum            patan dhoka
# 118    patan museum       Pimbahal Pokhari
# 170    patan museum     khumbeshwar temple
#
#                                              image_url
# 0    https://visitsnepal.com/wp-content/uploads/202...
# 24   https://i.pinimg.com/originals/aa/4c/ad/aa4cad...
# 13   https://dynamic-media-cdn.tripadvisor.com/medi...
# 5    https://www.holidify.com/images/cmsuploads/com...
# 28   https://dynamic-media-cdn.tripadvisor.com/medi...
# ..                                                 ...
# 145  https://www.templepurohit.com/wp-content/uploa...
# 137  https://www.vivaanadventure.com/wp-content/upl...
# 96   https://dynamic-media-cdn.tripadvisor.com/medi...
# 118  https://preview.redd.it/5ik7g9n53r861.jpg?auto...
# 170  https://dynamic-media-cdn.tripadvisor.com/medi...
#
# [324 rows x 3 columns]
